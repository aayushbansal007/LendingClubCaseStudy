# %% [markdown]
# <h1 style = "color : Brown"> Lending Club Case Study</h1>
#
# Lending Club is a consumer finance company which specialises in lending various types of loans to urban customers.
#
# <h2 style = "color : Brown"> Problem Statement</h2>
#
# There are two types of risks associated with the bank for approving loan applications:-
# <ul>
#     <li>If the applicant is likely to pay loan but his/her application get rejected.</li>
#     <li>If the applicant is not likely to pay the loan then he/she will default the loan in future</li>
# </ul>

# %% [markdown]
# <h2 style = "color : Brown"> Importing Libraries</h2>
# Following libraries will be used during this case study:-
# <ul>
#     <li>numpy</li>
#     <li>matplotlib</li>
#     <li>pandas</li>
#     <li>seaborn</li>
# </ul>

# %%
#Load the libraryss
import pandas as pd #To work with dataset
import numpy as np #Math library
import seaborn as sns #Graph library that use matplot in background
import matplotlib.pyplot as plt #to plot some parameters in seaborn
import random #Using it for generating random values

import matplotlib as mpl
# %matplotlib inline

# %% [markdown]
# <h2 style = "color : Brown"> Read the dataset</h2>
# We will read the data using read_csv() function of pandas library

# %%
df_lendingcase = pd.read_csv("loan.csv",index_col=0)
# Out:
# C:\Users\bansa\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# <h2 style = "color : Brown"> Data Exploration</h2>
# We will look for 5 top rows using head() function

# %%
#Looking at the data
df_lendingcase.head(5)
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1077501    1296599       5000         5000           4975.0   36 months
# 1077430    1314167       2500         2500           2500.0   60 months
# 1077175    1313524       2400         2400           2400.0   36 months
# 1076863    1277178      10000        10000          10000.0   36 months
# 1075358    1311748       3000         3000           3000.0   60 months
#
#         int_rate  installment grade sub_grade                 emp_title  ...  \
# id                                                                       ...
# 1077501   10.65%       162.87     B        B2                       NaN  ...
# 1077430   15.27%        59.83     C        C4                     Ryder  ...
# 1077175   15.96%        84.33     C        C5                       NaN  ...
# 1076863   13.49%       339.31     C        C1       AIR RESOURCES BOARD  ...
# ...

# %% [markdown]
# <h2>describe() function will provide us with count, mean, standard deviation (std), min, max, Interquartile range</h2>

# %%
#Searching for Missings,type of data and also known the shape of data
df_lendingcase.describe()
# Out:
#           member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  3.971700e+04  39717.000000  39717.000000     39717.000000
# mean   8.504636e+05  11219.443815  10947.713196     10397.448868
# std    2.656783e+05   7456.670694   7187.238670      7128.450439
# min    7.069900e+04    500.000000    500.000000         0.000000
# 25%    6.667800e+05   5500.000000   5400.000000      5000.000000
# 50%    8.508120e+05  10000.000000   9600.000000      8975.000000
# 75%    1.047339e+06  15000.000000  15000.000000     14400.000000
# max    1.314167e+06  35000.000000  35000.000000     35000.000000
#
#         installment    annual_inc           dti   delinq_2yrs  inq_last_6mths  \
# count  39717.000000  3.971700e+04  39717.000000  39717.000000    39717.000000
# mean     324.561922  6.896893e+04     13.315130      0.146512        0.869200
# std      208.874874  6.379377e+04      6.678594      0.491812        1.070219
# ...

# %% [markdown]
# <h2>First we will remove all the rows with loan_status = "Current"</h2>

# %%
#Getting shape of data
df_lendingcase.shape
# Out:
# (39717, 110)

# %%
# removing rows where loan_status = "Current"
df_lendingcase = df_lendingcase[df_lendingcase.loan_status != "Current"]

# %%
df_lendingcase.shape
# Out:
# (38577, 110)

# %%
# Looking at the data after removing rows with loan_status = "Current" 
df_lendingcase.describe()
# Out:
#           member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  3.857700e+04  38577.000000  38577.000000     38577.000000
# mean   8.422843e+05  11047.025430  10784.058506     10222.481123
# std    2.644519e+05   7348.441646   7090.306027      7022.720644
# min    7.069900e+04    500.000000    500.000000         0.000000
# 25%    6.611310e+05   5300.000000   5200.000000      5000.000000
# 50%    8.392920e+05   9600.000000   9550.000000      8733.440000
# 75%    1.037336e+06  15000.000000  15000.000000     14000.000000
# max    1.314167e+06  35000.000000  35000.000000     35000.000000
#
#         installment    annual_inc           dti   delinq_2yrs  inq_last_6mths  \
# count  38577.000000  3.857700e+04  38577.000000  38577.000000    38577.000000
# mean     322.466318  6.877797e+04     13.272727      0.146668        0.871737
# std      208.639215  6.421868e+04      6.673044      0.492271        1.071546
# ...

# %%
# df_lendingcase.dropna(how='all')

# %% [markdown]
# <h2>Droping all the columns with null values</h2>
# we will drop all the columns with null value as these data won't help us with the ML/AI model

# %%
df_lendingcase.drop(['annual_inc_joint','dti_joint','verification_status_joint','acc_now_delinq','tot_coll_amt','tot_cur_bal','open_acc_6m','open_il_6m','open_il_12m','open_il_24m','mths_since_rcnt_il','total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','total_rev_hi_lim','inq_fi','total_cu_tl','inq_last_12m','acc_open_past_24mths','avg_cur_bal','bc_open_to_buy','bc_util','chargeoff_within_12_mths','delinq_amnt','mo_sin_old_il_acct','mo_sin_old_rev_tl_op','mo_sin_rcnt_rev_tl_op','mo_sin_rcnt_tl','mort_acc','mths_since_recent_bc','mths_since_recent_bc_dlq','mths_since_recent_inq','mths_since_recent_revol_delinq','num_accts_ever_120_pd','num_actv_bc_tl','num_actv_rev_tl','num_bc_sats','num_bc_tl','num_il_tl','num_op_rev_tl','num_rev_accts','num_rev_tl_bal_gt_0','num_sats','num_tl_120dpd_2m','num_tl_30dpd','num_tl_90g_dpd_24m','num_tl_op_past_12m','pct_tl_nvr_dlq','percent_bc_gt_75','pub_rec_bankruptcies','tax_liens','tot_hi_cred_lim','total_bal_ex_mort','total_bc_limit','total_il_high_credit_limit','mths_since_last_major_derog','next_pymnt_d','mths_since_last_record','mths_since_last_delinq' ], axis = 1, inplace= True)

# %%
# Looking at the data after removl of columns with null values
df_lendingcase.describe()
# Out:
#           member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  3.857700e+04  38577.000000  38577.000000     38577.000000
# mean   8.422843e+05  11047.025430  10784.058506     10222.481123
# std    2.644519e+05   7348.441646   7090.306027      7022.720644
# min    7.069900e+04    500.000000    500.000000         0.000000
# 25%    6.611310e+05   5300.000000   5200.000000      5000.000000
# 50%    8.392920e+05   9600.000000   9550.000000      8733.440000
# 75%    1.037336e+06  15000.000000  15000.000000     14000.000000
# max    1.314167e+06  35000.000000  35000.000000     35000.000000
#
#         installment    annual_inc           dti   delinq_2yrs  inq_last_6mths  \
# count  38577.000000  3.857700e+04  38577.000000  38577.000000    38577.000000
# mean     322.466318  6.877797e+04     13.272727      0.146668        0.871737
# std      208.639215  6.421868e+04      6.673044      0.492271        1.071546
# ...

# %% [markdown]
# <h2>Droping column that will not impact our analysis:-</h2>
# We will drop below columns that have less impact on our analysis
# <ul>
#     <li>pymnt_plan</li>
#     <li>url</li>
#     <li>desc</li>
#     <li>issue_d</li>
#     <li>title</li>
#     <li>dti</li>
#     <li>delinq_2yrs</li>
#     <li>earliest_cr_line	</li>
#     <li>inq_last_6mths	</li>
#     <li>open_acc	</li>
#     <li>pub_rec</li>
#     <li>total_rec_late_fee	</li>
#     <li>recoveries	</li>
#     <li>collection_recovery_fee	last_pymnt_d	</li>
#     <li>last_pymnt_amnt		</li>
#     <li>last_credit_pull_d	</li>
#     <li>collections_12_mths_ex_med	</li>
#     <li>mths_since_last_major_derog	</li>
#     <li>policy_code</li>
#     <li>out_prncp</li>
#     <li>zip_code</li>
#     <li>addr_state</li>
# </ul>

# %%
df_lendingcase.drop(['pymnt_plan','url','desc','issue_d','title','dti','delinq_2yrs','earliest_cr_line','inq_last_6mths','open_acc','pub_rec','total_rec_late_fee','recoveries','collection_recovery_fee','last_pymnt_d','last_pymnt_amnt','last_credit_pull_d','collections_12_mths_ex_med','policy_code','out_prncp','out_prncp_inv','zip_code','addr_state' ], axis = 1, inplace= True)

# %%
# Looking at the data after removl of columns
df_lendingcase.describe()
# Out:
#           member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  3.857700e+04  38577.000000  38577.000000     38577.000000
# mean   8.422843e+05  11047.025430  10784.058506     10222.481123
# std    2.644519e+05   7348.441646   7090.306027      7022.720644
# min    7.069900e+04    500.000000    500.000000         0.000000
# 25%    6.611310e+05   5300.000000   5200.000000      5000.000000
# 50%    8.392920e+05   9600.000000   9550.000000      8733.440000
# 75%    1.037336e+06  15000.000000  15000.000000     14000.000000
# max    1.314167e+06  35000.000000  35000.000000     35000.000000
#
#         installment    annual_inc      revol_bal     total_acc   total_pymnt  \
# count  38577.000000  3.857700e+04   38577.000000  38577.000000  38577.000000
# mean     322.466318  6.877797e+04   13289.489826     22.052648  11866.970365
# std      208.639215  6.421868e+04   15866.492241     11.425861   8809.856227
# ...

# %% [markdown]
# <h2>We will analyse the data before doing the further changes.</h2>

# %%
#Searching for Missings,type of data and also known the shape of data
df_lendingcase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38577 entries, 1077501 to 87023
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   member_id            38577 non-null  int64
#  1   loan_amnt            38577 non-null  int64
#  2   funded_amnt          38577 non-null  int64
#  3   funded_amnt_inv      38577 non-null  float64
#  4   term                 38577 non-null  object
#  5   int_rate             38577 non-null  object
#  6   installment          38577 non-null  float64
#  7   grade                38577 non-null  object
#  8   sub_grade            38577 non-null  object
#  9   emp_title            36191 non-null  object
#  10  emp_length           37544 non-null  object
#  11  home_ownership       38577 non-null  object
#  12  annual_inc           38577 non-null  float64
#  13  verification_status  38577 non-null  object
#  14  loan_status          38577 non-null  object
# ...

# %% [markdown]
# <h2>Change data types of few columns</h2>
# Changing data type of few columns that will help us plotting the graph better

# %%
#removing special character '%' from the column int_rate and then converting it to float
df_lendingcase['int_rate'] = df_lendingcase['int_rate'].str.replace('%', '')
df_lendingcase['int_rate'] = df_lendingcase['int_rate'].astype(float)

# %%
#removing special character '%' from the column revol_util and then converting it to float
df_lendingcase['revol_util'] = df_lendingcase['revol_util'].str.replace('%', '')
df_lendingcase['revol_util'] = df_lendingcase['revol_util'].astype(float)

# %%
#removing special character '%' from the column emp_length and then converting it to int
df_lendingcase['emp_length'] = df_lendingcase['emp_length'].str.replace('+', '')
df_lendingcase['emp_length'] = df_lendingcase['emp_length'].str.replace('years', '')
df_lendingcase['emp_length'] = df_lendingcase['emp_length'].str.replace('year', '')
df_lendingcase['emp_length'] = df_lendingcase['emp_length'].str.replace('<', '')
# replacing n/a with ranom number between 1 - 10
df_lendingcase['emp_length'] = df_lendingcase['emp_length'].str.replace('n/a', str(random.randint(1,10)))
df_lendingcase['emp_length'] = df_lendingcase['emp_length'].astype(float)
# Out:
# C:\Users\bansa\AppData\Local\Temp/ipykernel_24124/2981507846.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_lendingcase['emp_length'] = df_lendingcase['emp_length'].str.replace('+', '')

# %%
#Looking at the data
df_lendingcase.head(5)
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1077501    1296599       5000         5000           4975.0   36 months
# 1077430    1314167       2500         2500           2500.0   60 months
# 1077175    1313524       2400         2400           2400.0   36 months
# 1076863    1277178      10000        10000          10000.0   36 months
# 1075269    1311441       5000         5000           5000.0   36 months
#
#          int_rate  installment grade sub_grade             emp_title  ...  \
# id                                                                    ...
# 1077501     10.65       162.87     B        B2                   NaN  ...
# 1077430     15.27        59.83     C        C4                 Ryder  ...
# 1077175     15.96        84.33     C        C5                   NaN  ...
# 1076863     13.49       339.31     C        C1   AIR RESOURCES BOARD  ...
# 1075269      7.90       156.46     A        A4  Veolia Transportaton  ...
#
# ...

# %% [markdown]
# <h2>Look for missing values in the dataset</h2>

# %%
#checking missing values
df_lendingcase.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# member_id                 0
# loan_amnt                 0
# funded_amnt               0
# funded_amnt_inv           0
# term                      0
# int_rate                  0
# installment               0
# grade                     0
# sub_grade                 0
# emp_title              2386
# emp_length             1033
# home_ownership            0
# annual_inc                0
# verification_status       0
# loan_status               0
# purpose                   0
# revol_bal                 0
# revol_util               50
# total_acc                 0
# initial_list_status       0
# total_pymnt               0
# total_pymnt_inv           0
# total_rec_prncp           0
# total_rec_int             0
# application_type          0
# dtype: int64

# %% [markdown]
# <h2>Fill in missing values in the data set</h2>
# We will fill the missing value for columns revol_util and emp_length by getting there respective means
# We will fill the missing value of emp_title with "Company not filled"

# %%
df_lendingcase['revol_util'].fillna(df_lendingcase['revol_util'].mean(), inplace=True)

# %%
df_lendingcase['emp_length'].fillna(df_lendingcase['emp_length'].mean(), inplace=True)

# %%
df_lendingcase['emp_title'].fillna("Company not filled", inplace=True)

# %%
#checking missing values after filling the columns
df_lendingcase.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# member_id              0
# loan_amnt              0
# funded_amnt            0
# funded_amnt_inv        0
# term                   0
# int_rate               0
# installment            0
# grade                  0
# sub_grade              0
# emp_title              0
# emp_length             0
# home_ownership         0
# annual_inc             0
# verification_status    0
# loan_status            0
# purpose                0
# revol_bal              0
# revol_util             0
# total_acc              0
# initial_list_status    0
# total_pymnt            0
# total_pymnt_inv        0
# total_rec_prncp        0
# total_rec_int          0
# application_type       0
# dtype: int64

# %% [markdown]
# <h2>After Filling and changing the data type we will start the analysis of data</h2>

# %% [markdown]
# <h2>Univariate Analysis</h2>
#
# <h3>Categorical columns</h3>

# %%
#ploting bar graph for grade column
df_lendingcase.grade.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#ploting bar graph for sub_grade column
df_lendingcase.sub_grade.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#ploting bar graph for home_ownership column
df_lendingcase.home_ownership.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#ploting bar graph for verification_status column
df_lendingcase.verification_status.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#ploting bar graph for loan_status column
df_lendingcase.loan_status.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>Discrete Number columns</h3>

# %%
#ploting bar graph for term column
df_lendingcase.term.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#ploting bar graph for emp_length column
df_lendingcase.emp_length.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Box Plot of emp_length column
df_lendingcase.boxplot(column='emp_length')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>Continous Number columns</h3>

# %%
#outlier removal functions
def outlier_IQR_method_remove(df):
    A1=df.quantile(0.25)
    A3=df.quantile(0.75)
    IQR=A3-A1
    df_final_lendingcase=df[~((df<(A1-1.5*IQR)) | (df>(A3+1.5*IQR)))]
    return df_final_lendingcase

# %% [markdown]
# <h4>Column loan_amnt</h4>

# %%
#Historigram of loan_amnt column
df_lendingcase['loan_amnt'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
#boxplot of loan_amnt column
df_lendingcase.boxplot(column='loan_amnt')
# Out:
# <AxesSubplot:>

# %%
#removing outliers in loan_amnt column
df_outlier_removed=outlier_IQR_method_remove(df_lendingcase.loan_amnt)
df_outlier_removed=pd.DataFrame(df_outlier_removed)
ind_diff=df_lendingcase.index.difference(df_outlier_removed.index)

for i in range(0, len(ind_diff),1):
    df_final_lendingcase=df_lendingcase.drop([ind_diff[i]])
    df_lendingcase=df_final_lendingcase

# %%
df_lendingcase.boxplot(column='loan_amnt')
# Out:
# <AxesSubplot:>

# %%
#Historigram of loan_amnt column after removal of outliers
df_lendingcase['loan_amnt'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h4>Column funded_amnt</h4>

# %%
#Historigram of funded_amnt column
df_lendingcase['funded_amnt'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
#boxplot of funded_amnt column
df_lendingcase.boxplot(column='funded_amnt')
# Out:
# <AxesSubplot:>

# %%
#removing outliers in funded_amnt column
df_outlier_removed=outlier_IQR_method_remove(df_lendingcase.funded_amnt)
df_outlier_removed=pd.DataFrame(df_outlier_removed)
ind_diff=df_lendingcase.index.difference(df_outlier_removed.index)

for i in range(0, len(ind_diff),1):
    df_final_lendingcase=df_lendingcase.drop([ind_diff[i]])
    df_lendingcase=df_final_lendingcase

# %%
#boxplot of funded_amnt column
df_lendingcase.boxplot(column='funded_amnt')
# Out:
# <AxesSubplot:>

# %%
#Historigram of funded_amnt column after removal of outliers

df_lendingcase['funded_amnt'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h4>Column funded_amnt_inv</h4>

# %%
#Historigram of funded_amnt_inv column
df_lendingcase['funded_amnt_inv'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
#boxplot of funded_amnt_inv column
df_lendingcase.boxplot(column='funded_amnt_inv')
# Out:
# <AxesSubplot:>

# %%
#removing outliers in funded_amnt_inv column
df_outlier_removed=outlier_IQR_method_remove(df_lendingcase.funded_amnt_inv)
df_outlier_removed=pd.DataFrame(df_outlier_removed)
ind_diff=df_lendingcase.index.difference(df_outlier_removed.index)

for i in range(0, len(ind_diff),1):
    df_final_lendingcase=df_lendingcase.drop([ind_diff[i]])
    df_lendingcase=df_final_lendingcase

# %%
#boxplot of funded_amnt_inv column
df_lendingcase.boxplot(column='funded_amnt_inv')
# Out:
# <AxesSubplot:>

# %%
#Historigram of funded_amnt_inv column after removal of outliers

df_lendingcase['funded_amnt_inv'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h4>Column installment</h4>

# %%
#Historigram of installment column
df_lendingcase['installment'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
#boxplot of installment column
df_lendingcase.boxplot(column='installment')
# Out:
# <AxesSubplot:>

# %%
#removing outliers in installment column
df_outlier_removed=outlier_IQR_method_remove(df_lendingcase.installment)
df_outlier_removed=pd.DataFrame(df_outlier_removed)
ind_diff=df_lendingcase.index.difference(df_outlier_removed.index)

for i in range(0, len(ind_diff),1):
    df_final_lendingcase=df_lendingcase.drop([ind_diff[i]])
    df_lendingcase=df_final_lendingcase

# %%
#boxplot of installment column
df_lendingcase.boxplot(column='installment')
# Out:
# <AxesSubplot:>

# %%
#Historigram of installment column after removal of outliers

df_lendingcase['installment'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h4>Column annual_inc</h4>

# %%
#Historigram of annual_inc column 
df_lendingcase['annual_inc'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
#boxplot of annual_inc column
df_lendingcase.boxplot(column='annual_inc')
# Out:
# <AxesSubplot:>

# %%
#removing outliers in annual_inc column
df_outlier_removed=outlier_IQR_method_remove(df_lendingcase.annual_inc)
df_outlier_removed=pd.DataFrame(df_outlier_removed)
ind_diff=df_lendingcase.index.difference(df_outlier_removed.index)

for i in range(0, len(ind_diff),1):
    df_final_lendingcase=df_lendingcase.drop([ind_diff[i]])
    df_lendingcase=df_final_lendingcase

# %%
df_lendingcase.boxplot(column='annual_inc')
# Out:
# <AxesSubplot:>

# %%
#Historigram of annual_inc column after removal of outliers
df_lendingcase['annual_inc'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2>Bivariate Analysis</h2>
#
# <h4>Analysing variables with respect to loan_status column</h4>

# %%
#Analysing term column
df_lendingcase.groupby('term').loan_status.value_counts().unstack().plot(kind='bar',figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='term'>

# %%
#Analysing grade column
df_lendingcase.groupby('grade').loan_status.value_counts().unstack().plot(kind='bar',figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='grade'>

# %%
#Analysing sub_grade column
df_lendingcase.groupby('sub_grade').loan_status.value_counts().unstack().plot(kind='bar',figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='sub_grade'>

# %%
#Analysing emp_length column
df_lendingcase.groupby('emp_length').loan_status.value_counts().unstack().plot(kind='bar',figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='emp_length'>

# %%
#Analysing home_ownership column
df_lendingcase.groupby('home_ownership').loan_status.value_counts().unstack().plot(kind='bar',figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='home_ownership'>

# %%
#Analysing verification_status column
df_lendingcase.groupby('verification_status').loan_status.value_counts().unstack().plot(kind='bar',figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='verification_status'>

# %%
#Analysing purpose column
df_lendingcase.groupby('purpose').loan_status.value_counts().unstack().plot(kind='bar',figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='purpose'>

# %%
#Analysing loan_amnt column
df_lendingcase.boxplot(column='loan_amnt', by='loan_status')
# Out:
# <AxesSubplot:title={'center':'loan_amnt'}, xlabel='loan_status'>

# %%
#Analysing int_rate column
df_lendingcase.boxplot(column='int_rate', by='loan_status')
# Out:
# <AxesSubplot:title={'center':'int_rate'}, xlabel='loan_status'>

# %%
#Analysing installment column
df_lendingcase.boxplot(column='installment', by='loan_status')
# Out:
# <AxesSubplot:title={'center':'installment'}, xlabel='loan_status'>

# %% [markdown]
# <h4>Analysing variables with respect to home_ownership column</h4>

# %%
df_lendingcase.boxplot(column='annual_inc', by='home_ownership')
# Out:
# <AxesSubplot:title={'center':'annual_inc'}, xlabel='home_ownership'>

# %%
df_lendingcase.boxplot(column='loan_amnt', by='home_ownership')
# Out:
# <AxesSubplot:title={'center':'loan_amnt'}, xlabel='home_ownership'>

# %%
df_lendingcase.boxplot(column='installment', by='home_ownership')
# Out:
# <AxesSubplot:title={'center':'installment'}, xlabel='home_ownership'>

# %% [markdown]
# <h4>Analysing variables with respect to verification_status column</h4>

# %%
df_lendingcase.boxplot(column='annual_inc', by='verification_status')
# Out:
# <AxesSubplot:title={'center':'annual_inc'}, xlabel='verification_status'>

# %%
df_lendingcase.boxplot(column='loan_amnt', by='verification_status')
# Out:
# <AxesSubplot:title={'center':'loan_amnt'}, xlabel='verification_status'>

# %%
df_lendingcase.boxplot(column='installment', by='verification_status')
# Out:
# <AxesSubplot:title={'center':'installment'}, xlabel='verification_status'>

# %% [markdown]
# <h4>Analysing variables with respect to annual_inc column</h4>

# %%
df_lendingcase.plot(x='annual_inc', y='loan_amnt', style='o',figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='annual_inc'>

# %%
df_lendingcase.plot(x='annual_inc', y='installment', style='o',figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='annual_inc'>

# %%
df_lendingcase.plot(x='annual_inc', y='int_rate', style='o',figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='annual_inc'>

# %% [markdown]
# <h2>MultiVariate Analysis</h2>

# %%
#coolwarm map  of all shortlisted columns together
df_lendingcase.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_24ac2_row0_col0, #T_24ac2_row1_col1, #T_24ac2_row2_col2, #T_24ac2_row3_col3, #T_24ac2_row4_col4, #T_24ac2_row5_col5, #T_24ac2_row6_col6, #T_24ac2_row7_col7, #T_24ac2_row8_col8, #T_24ac2_row9_col9, #T_24ac2_row10_col10, #T_24ac2_row11_col11, #T_24ac2_row12_col12, #T_24ac2_row13_col13, #T_24ac2_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_24ac2_row0_col1, #T_24ac2_row0_col5, #T_24ac2_row0_col8, #T_24ac2_row0_col11, #T_24ac2_row0_col14, #T_24ac2_row4_col6, #T_24ac2_row4_col7, #T_24ac2_row4_col10, #T_24ac2_row8_col0, #T_24ac2_row9_col2, #T_24ac2_row9_col3, #T_24ac2_row9_col12, #T_24ac2_row9_col13, #T_24ac2_row10_col4, #T_24ac2_row10_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_24ac2_row0_col2, #T_24ac2_row9_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# ...

# %%
#Corelation Matrix of all available columns
f = plt.figure(figsize=(19, 15))
plt.matshow(df_lendingcase.corr(), fignum=f.number)
plt.xticks(range(df_lendingcase.select_dtypes(['number']).shape[1]), df_lendingcase.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df_lendingcase.select_dtypes(['number']).shape[1]), df_lendingcase.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16)
sns.heatmap(df_lendingcase.corr(),vmin=-1.0,vmax=1.0,annot=True, cmap="YlGnBu")
# Out:
# <Axes:title={'center':'Correlation Matrix'}>

# %%
columns_shortlisted= ["annual_inc","loan_amnt","int_rate","funded_amnt_inv","term","grade","purpose","loan_status","home_ownership","verification_status"]
df_lendingcase[columns_shortlisted].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f39b2_row0_col0, #T_f39b2_row1_col1, #T_f39b2_row2_col2, #T_f39b2_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f39b2_row0_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_f39b2_row0_col2, #T_f39b2_row2_col0, #T_f39b2_row2_col1, #T_f39b2_row2_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f39b2_row0_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_f39b2_row1_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_f39b2_row1_col2, #T_f39b2_row3_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_f39b2_row1_col3, #T_f39b2_row3_col1 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_f39b2_row3_col0 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# </style>
# <table id="T_f39b2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >annual_inc</th>
# ...

# %%
corrMatrix = df_lendingcase[columns_shortlisted].corr()
print (corrMatrix)
# Out:
#                  annual_inc  loan_amnt  int_rate  funded_amnt_inv
# annual_inc         1.000000   0.329658 -0.001961         0.308346
# loan_amnt          0.329658   1.000000  0.217348         0.919279
# int_rate          -0.001961   0.217348  1.000000         0.221066
# funded_amnt_inv    0.308346   0.919279  0.221066         1.000000

# %% [markdown]
# <h2>Conclusions:</h2>
# Following are the columns that can help our predictive model to identify the loans that may become default.
# <ul>
#     <li>annual_inc</li>
#     <li>loan_amnt</li>
#     <li>int_rate</li>
#     <li>funded_amnt_inv</li>
#     <li>term</li>
#     <li>grade</li>
#     <li>purpose</li>
#     <li>loan_status</li>
# </ul>
